# %% [markdown]
# <a href="https://colab.research.google.com/github/Ammara-Hussain/flyrank-internship-assignments/blob/main/w03_identity_kit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🆔 Identity Kit — Ammara Hussain
#
# ### 1. Typography
# * **Heading Font:** Plus Jakarta Sans (Weight: 700)
# * **Body Font:** Inter (Weight: 400 / 500)
#
# ---
#
# ### 2. Color Palette
# * **Background (Near-White):** `#F8F9FA`
# * **Primary Text (Near-Black):** `#1A1D20`
# * **Brand / Primary:** `#1E293B`
# * **Accent Color:** `#2563EB`
#
# ---
#
# ### 3. Logo & Favicon
# * **Text Logo:** AMMARA HUSSAIN (Plus Jakarta Sans Bold, Uppercase, #1E293B)
# * **Favicon Monogram:** `[ AH ]` (White text on `#1E293B` rounded square)
#
# ---
#
# ### 4. Two-Line Style Note
# > **Style Note:**
# > Headings in *Plus Jakarta Sans* (`#1E293B`), Body in *Inter* (`#1A1D20`) on background (`#F8F9FA`), with accent (`#2563EB`).
# > **Mood:** Minimalist, high-rigor engineering portfolio—clean typography and muted contrast that lets the data and code speak for itself.
