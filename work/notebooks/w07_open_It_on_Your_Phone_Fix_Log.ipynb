# %% [markdown]
# <a href="https://colab.research.google.com/github/Ammara-Hussain/flyrank-internship-assignments/blob/main/work/notebooks/w07_open_It_on_Your_Phone_Fix_Log.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Deliverable URL**

# %% [markdown]
# https://ammarahussain-portfolio.netlify.app/

# %% [markdown]
# #**Open It on Your Phone — Fix Log**

# %% [markdown]
# **Live Portfolio URL:**
# https://ammarahussain-portfolio.netlify.app/
#
# **Mobile Testing**
#
# I opened my portfolio on a real mobile phone and checked the homepage, navigation, project cards, project images, text readability, contact page, and links. I also checked the portfolio on desktop.
#
# **Issue Found**
#
# Raw ```html text was accidentally visible at the top of the homepage. It appeared on both mobile and desktop and was not part of the intended website content.
#
# **Fix Applied**
#
# I removed the unnecessary ```html text from the homepage HTML and redeployed the website through Netlify.
#
# **Result**
#
# The unwanted text was removed, and the portfolio now displays the intended homepage content correctly on both mobile and desktop.
#
# **Additional Checks**
#
# **I checked:**
#
# Mobile navigation
# Text readability
# Project card layout
# Project image sizing
# View Project links
# GitHub links
# LinkedIn link
# Contact page
#
# All tested links are working correctly.
#
# **Before and After Evidence**
#
# **Before:** The ```html text was visible at the top of the webpage.
#
# **After:** The unwanted text was removed and the live portfolio displays correctly.
