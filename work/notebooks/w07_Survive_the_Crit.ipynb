# %% [markdown]
# <a href="https://colab.research.google.com/github/Ammara-Hussain/flyrank-internship-assignments/blob/main/work/notebooks/w07_Survive_the_Crit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Survive the Crit — Portfolio Review**

# %% [markdown]
# **Portfolio URL:**
# https://ammarahussain-portfolio.netlify.app/
#
# **Proof Statement**
#
# I’m a Software Engineering student building practical software through programming and problem-solving, with projects in web development, Java, and software design.
#
# **Reviewer Questions**
#
# **Q1. In ten seconds, what do I do?**
#
# You are a Software Engineering student who builds practical software through programming and problem-solving.
#
# **Q2. Would you believe I'm good at it?**
#
# I would believe that you have practical development experience because the portfolio shows several completed projects using different technologies. However, the project descriptions need more specific technical evidence before I could confidently judge your level of ability.
#
# **Feedback**
#
# The portfolio communicates my identity as a Software Engineering student clearly and presents several real projects. The design is clean and the navigation is understandable. However, the project descriptions are somewhat generic and focus more on what each project is than on what I personally implemented, what technical problems I solved, and what the outcome was.
#
# **Must-Fix**
# Make the homepage positioning more specific.
# Strengthen project descriptions with concrete technical details and contributions.
# Make the main “View Projects” action more prominent.
# **Nice-to-Have**
# Add detailed case studies.
# Add a stronger AI/ML project to support my stated interest.
# Expand the contact section with CV and other professional links.
# **Changes Made**
#
# I revised my homepage positioning to clearly state that I build practical software through programming and problem-solving. I also improved the project descriptions to provide more specific information about the technologies and functionality implemented. I then redeployed the updated portfolio on Netlify and checked the live site.
#
# **Important:** only write that last paragraph after you actually make those changes. That gives you the required evidence that the must-fixes were addressed on the live site.
