# %% [markdown]
# <a href="https://colab.research.google.com/github/Ammara-Hussain/flyrank-internship-assignments/blob/main/w03_Content_Map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🗺️ Portfolio Content Map & Through-Line
#
# ## 1. One-Line Claim
# > **"Software engineering student building structured web applications, secure Node.js REST APIs, and robust SQL database architectures."**
#
# ---
#
# ## 2. Content Map
#
# ### 📄 Page 1: Home / Portfolio Overview (Root)
# * **Section 1: Hero Section**
#   * One-line claim + Identity Kit styling + Brief bio.
# * **Section 2: Lead Project — Backend REST API Architecture**
#   * *Case Study:* **Node.js & Express API with Postman Verification**.
#   * Highlights: Modular routing, async exception handling, input validation, and HTTP status code standards.
# * **Section 3: Database Design & Query Optimization**
#   * *Case Study:* **Relational Database Management System (Oracle SQL)**.
#   * Highlights: Entity-Relationship (ER) modeling, schema normalization, multi-table JOINs, and integrity constraints.
# * **Section 4: Web Development & Scripting Utilities**
#   * *Case Study:* **Full-Stack Interfaces & Python Utility Scripts**.
#   * Highlights: Responsive HTML/CSS/JS frontend integration, Postman test suites, and Google Colab Python scripts.
# * **Section 5: Footer & Primary Call to Action**
#   * **CTA:** *"Looking for a backend or software engineering intern? [Schedule a Call / Send an Email]"*
#
# ---
#
# ### 📄 Page 2: Case Study — Node.js/Express REST API & Postman Suite
# * **Section 1: Executive Summary**
#   * Problem context, API route architecture, and system data flow.
# * **Section 2: Endpoint Security & Code Quality**
#   * Refactoring async handlers, parameter sanitization, and structured JSON error responses.
# * **Section 3: API Testing & Verification**
#   * Postman collection testing runs, response code validation, and route output logs.
# * **Section 4: Next Step CTA**
#   * **CTA:** *"View the API source code on GitHub → [Link]"*
#
# ---
#
# ### 📄 Page 3: Case Study — Oracle SQL Schema & Software Architecture
# * **Section 1: Architectural Design**
#   * Modular software design patterns, component relationships, and ER diagram mapping.
# * **Section 2: Oracle SQL Data Model**
#   * Relational database schema setup, primary/foreign key constraints, and optimized queries.
# * **Section 3: Automation Scripts**
#   * Python utility scripts (Google Colab) for data processing and automated reporting.
# * **Section 4: Next Step CTA**
#   * **CTA:** *"Review the database schema and architecture docs → [Contact Me]"*
#
# ---
#
# ## 3. "Still Need to Gather" List
#
# | Needed Asset | Source / Location | Status | Action Required |
# | :--- | :--- | :--- | :--- |
# | **GitHub Repo Links** | API & Software Repositories | ⏳ Pending | Clean up README files and verify repository visibility. |
# | **Postman Collection Export** | Node.js Backend API | ⏳ Pending | Export `.json` test collection from Postman. |
# | **Terminal/Console Screenshots** | Development Environment | ✅ Ready | Captured from Node.js runtime and database logs. |
# | **Profile Photo** | Headshot | ✅ Ready | `profile picture_2.png` captured. |
