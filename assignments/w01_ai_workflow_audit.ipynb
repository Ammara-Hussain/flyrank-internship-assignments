# %% [markdown]
# <a href="https://colab.research.google.com/github/Ammara-Hussain/flyrank-internship-assignments/blob/main/assignments/w01_ai_workflow_audit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Phase: Setup | AI Workflow Audit
#
# | Task Name | Classification | One-line Rationale |
# | :--- | :--- | :--- |
# | **1. Reading Quran** | Just me | Spiritual practice and personal reflection require pure personal devotion and intent that cannot be outsourced. |
# | **2. Designing slides for my lectures** | Delegate to AI with review | AI can quickly structure structural bullet points and slide layouts, which I review to ensure clarity. |
# | **3. Reading articles/books** | Just me | Active reading is critical for building deep comprehension, personal focus, and independent vocabulary growth. |
# | **4. Implementing internship projects** | Collaborate with AI | I write the core logic and build features, using AI alongside me to troubleshoot bugs and structure logic flows. |
# | **5. Drafting academic reports & assignments** | Collaborate with AI | I supply the factual data and technical research, using AI to help refine the document format and professional phrasing. |
# | **6. Learning & interpreting internship briefs** | Collaborate with AI | AI helps break down complex technical criteria into simplified, actionable steps so I can study them effectively. |
# | **7. Teaching students / peers** | Just me | Human mentorship requires real-time empathy, direct communication, and understanding a student's individual confusion. |
# | **8. Taking online training courses** | Just me | Gaining actual foundational certification requires my own intellectual processing to build real engineering capabilities. |
# | **9. Reviewing and digesting lecture slides** | Collaborate with AI | I provide confusing technical lecture slides, and AI helps summarize the core conceptual takeaways for quicker study. |
# | **10. Fixing basic code syntax or runtime errors** | Delegate to AI with review | AI spots missing brackets or typos instantly, allowing me to fix errors without wasting diagnostic time. |
# | **11. Organizing fundraising logistics & public updates** | Collaborate with AI | I supply the raw financial or collection data, and AI helps format it cleanly for public clarity and transparency reports. |
# | **12. Watching spiritual upliftment video lectures and self development exercises** | Just me | Internal growth, character building, and emotional processing require active personal presence and self-reflection. |

# %% [markdown]
# ### Target Tasks & Measurable Success Definitions
#
# 1. **Target Task: Implementing Internship Projects**
#    * **Definition of "Done Well":** The final feature functions flawlessly, aligns perfectly with the codebase layout, passes validation tests, and reduces my basic logic drafting time by 40%.
#
# 2. **Target Task: Reviewing and Digesting Lecture Slides**
#    * **Definition of "Done Well":** Complex technological slide decks are simplified into scannable summaries that highlight key algorithms/terms, cutting down my exam study review time by half.
#
# 3. **Target Task: Drafting Academic Reports & Assignments**
#    * **Definition of "Done Well":** Deliverables are structurally complete, use flawless technical phrasing, match all academic submission rubrics, and require less than 5 minutes of manual line edits before saving.

# %% [markdown]
# ### 1. Tool Setup: Claude  Project
# ![Project_Setup2.png](data:image/png;base64,...)
# ![Project_Setup3.png](data:image/png;base64,...)
# ![Project_Setup1.png](data:image/png;base64,...)
#
#
#
#
# ---
#
# ### 2. Education Setup: Anthropic Academy Enrollment
# ![AI Fluency01.png](data:image/png;base64,...)

# %% [markdown]
# ### Evidence: Tools Sign-Up
# ![claude sign up.png](data:image/png;base64,...)
# ![Anthropic sign up.png](data:image/png;base64,...)
# ![chatgpt.png](data:image/png;base64,...)
